# %%
import matplotlib.pyplot as plt

# Plotting Latency vs. Node
plt.figure(figsize=(10, 6))
plt.scatter(coap_client_results['Node'], coap_client_results['Latency'], color='blue', label='CoAP Latency')
plt.title('CoAP Latency vs. Node')
plt.xlabel('Node')
plt.ylabel('Latency (s)')
plt.legend()
plt.show()

# Plotting Throughput vs. Node
plt.figure(figsize=(10, 6))
plt.scatter(coap_client_results['Node'], coap_client_results['Throughput'], color='green', label='CoAP Throughput')
plt.title('CoAP Throughput vs. Node')
plt.xlabel('Node')
plt.ylabel('Throughput (Bytes/s)')
plt.legend()
plt.show()


# Cell 4: Save Plots and Data

# Save the plots as images
plt.figure(figsize=(10, 6))
plt.scatter(coap_client_results['Node'], coap_client_results['Latency'], color='blue', label='CoAP Latency')
plt.title('CoAP Latency vs. Node')
plt.xlabel('Node')
plt.ylabel('Latency (s)')
plt.legend()
plt.savefig('coap_latency_vs_node.png')

plt.figure(figsize=(10, 6))
plt.scatter(coap_client_results['Node'], coap_client_results['Throughput'], color='green', label='CoAP Throughput')
plt.title('CoAP Throughput vs. Node')
plt.xlabel('Node')
plt.ylabel('Throughput (Bytes/s)')
plt.legend()
plt.savefig('coap_throughput_vs_node.png')

# Save the results DataFrame to a CSV file
coap_client_results.to_csv('coap_client_results.csv', index=False)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load CoAP client results
coap_client_results = pd.read_csv('coap_client_results.csv')
# coap_client_results = pd.read_csv('coap_client_results_blockwise.csv')
# Load HTTP client results
http_client_results = pd.read_csv('http_client_results.csv')

# Plot CoAP Latency vs Message Size
plt.figure(figsize=(12, 6))
for node in coap_client_results['Node'].unique():
    data = coap_client_results[coap_client_results['Node'] == node]
    plt.plot(data['Message_Size'], data['Latency'], label=f'Node {node}', marker='o')

plt.title('CoAP Latency vs Message Size')
plt.xlabel('Message Size')
plt.ylabel('Latency (s)')
plt.legend()
plt.show()

# Plot HTTP Latency vs Message Size
plt.figure(figsize=(12, 6))
for node in http_client_results['Node'].unique():
    data = http_client_results[http_client_results['Node'] == node]
    plt.plot(data['Message_Size'], data['Latency'], label=f'Node {node}', marker='o')

plt.title('HTTP Latency vs Message Size')
plt.xlabel('Message Size')
plt.ylabel('Latency (s)')
plt.legend()
plt.show()

# Plot CoAP Throughput vs Message Size
plt.figure(figsize=(12, 6))
for node in coap_client_results['Node'].unique():
    data = coap_client_results[coap_client_results['Node'] == node]
    plt.plot(data['Message_Size'], data['Throughput'], label=f'Node {node}', marker='o')

plt.title('CoAP Throughput vs Message Size')
plt.xlabel('Message Size')
plt.ylabel('Throughput (Bytes/s)')
plt.legend()
plt.show()

# Plot HTTP Throughput vs Message Size
plt.figure(figsize=(12, 6))
for node in http_client_results['Node'].unique():
    data = http_client_results[http_client_results['Node'] == node]
    plt.plot(data['Message_Size'], data['Throughput'], label=f'Node {node}', marker='o')

plt.title('HTTP Throughput vs Message Size')
plt.xlabel('Message Size')
plt.ylabel('Throughput (Bytes/s)')
plt.legend()
plt.show()

# Plot CoAP Total Time vs Node
plt.figure(figsize=(12, 6))
plt.bar(coap_client_results['Node'], coap_client_results['Total_Time'])
plt.title('CoAP Total Time vs Node')
plt.xlabel('Node')
plt.ylabel('Total Time (s)')
plt.show()

# Plot HTTP Total Time vs Node
plt.figure(figsize=(12, 6))
plt.bar(http_client_results['Node'], http_client_results['Total_Time'])
plt.title('HTTP Total Time vs Node')
plt.xlabel('Node')
plt.ylabel('Total Time (s)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load CoAP client results
# coap_client_results = pd.read_csv('coap_client_results.csv')
coap_client_results = pd.read_csv('coap_client_results_blockwise.csv')
# Load HTTP client results
http_client_results = pd.read_csv('http_client_results.csv')

# Plot CoAP Latency vs Message Size
plt.figure(figsize=(12, 6))
for node in coap_client_results['Node'].unique():
    data = coap_client_results[coap_client_results['Node'] == node]
    plt.plot(data['Message_Size'], data['Latency'], label=f'Node {node}', marker='o')

plt.title('CoAP Latency vs Message Size')
plt.xlabel('Message Size')
plt.ylabel('Latency (s)')
plt.legend()
plt.show()

# Plot HTTP Latency vs Message Size
plt.figure(figsize=(12, 6))
for node in http_client_results['Node'].unique():
    data = http_client_results[http_client_results['Node'] == node]
    plt.plot(data['Message_Size'], data['Latency'], label=f'Node {node}', marker='o')

plt.title('HTTP Latency vs Message Size')
plt.xlabel('Message Size')
plt.ylabel('Latency (s)')
plt.legend()
plt.show()

# Plot CoAP Throughput vs Message Size
plt.figure(figsize=(12, 6))
for node in coap_client_results['Node'].unique():
    data = coap_client_results[coap_client_results['Node'] == node]
    plt.plot(data['Message_Size'], data['Throughput'], label=f'Node {node}', marker='o')

plt.title('CoAP Throughput vs Message Size')
plt.xlabel('Message Size')
plt.ylabel('Throughput (Bytes/s)')
plt.legend()
plt.show()

# Plot HTTP Throughput vs Message Size
plt.figure(figsize=(12, 6))
for node in http_client_results['Node'].unique():
    data = http_client_results[http_client_results['Node'] == node]
    plt.plot(data['Message_Size'], data['Throughput'], label=f'Node {node}', marker='o')

plt.title('HTTP Throughput vs Message Size')
plt.xlabel('Message Size')
plt.ylabel('Throughput (Bytes/s)')
plt.legend()
plt.show()

# Plot CoAP Total Time vs Node
plt.figure(figsize=(12, 6))
plt.bar(coap_client_results['Node'], coap_client_results['Total_Time'])
plt.title('CoAP Total Time vs Node')
plt.xlabel('Node')
plt.ylabel('Total Time (s)')
plt.show()

# Plot HTTP Total Time vs Node
plt.figure(figsize=(12, 6))
plt.bar(http_client_results['Node'], http_client_results['Total_Time'])
plt.title('HTTP Total Time vs Node')
plt.xlabel('Node')
plt.ylabel('Total Time (s)')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load Vanilla CoAP client results
coap_client_results_vanilla = pd.read_csv('coap_client_results.csv')

# Load CoAP client with Block-Wise Transfer results
coap_client_results_blockwise = pd.read_csv('coap_client_results_blockwise.csv')

# Plot CoAP Latency vs Message Size (Vanilla vs Block-Wise)
plt.figure(figsize=(12, 6))
plt.plot(coap_client_results_vanilla['Message_Size'], coap_client_results_vanilla['Latency'], label='Vanilla', marker='o')
plt.plot(coap_client_results_blockwise['Message_Size'], coap_client_results_blockwise['Latency'], label='Block-Wise', marker='o')
plt.title('CoAP Latency vs Message Size')
plt.xlabel('Message Size')
plt.ylabel('Latency (s)')
plt.legend()
plt.show()

# Plot CoAP Throughput vs Message Size (Vanilla vs Block-Wise)
plt.figure(figsize=(12, 6))
plt.plot(coap_client_results_vanilla['Message_Size'], coap_client_results_vanilla['Throughput'], label='Vanilla', marker='o')
plt.plot(coap_client_results_blockwise['Message_Size'], coap_client_results_blockwise['Throughput'], label='Block-Wise', marker='o')
plt.title('CoAP Throughput vs Message Size')
plt.xlabel('Message Size')
plt.ylabel('Throughput (Bytes/s)')
plt.legend()
plt.show()

# Plot CoAP Total Time vs Node (Vanilla vs Block-Wise)
plt.figure(figsize=(12, 6))
plt.bar(coap_client_results_vanilla['Node'], coap_client_results_vanilla['Total_Time'], label='Vanilla')
plt.bar(coap_client_results_blockwise['Node'], coap_client_results_blockwise['Total_Time'], label='Block-Wise', alpha=0.7)
plt.title('CoAP Total Time vs Node')
plt.xlabel('Node')
plt.ylabel('Total Time (s)')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load CoAP client results (Vanilla and Optimized)
coap_vanilla_results = pd.read_csv('coap_client_results.csv')
coap_optimized_results = pd.read_csv('coap_client_results_blockwise.csv')

# Load HTTP client results
http_results = pd.read_csv('http_client_results.csv')

# Plot Latency vs Message Size
plt.figure(figsize=(12, 6))
for node in range(1, 6):
    plt.plot(http_results[http_results['Node'] == node]['Message_Size'], http_results[http_results['Node'] == node]['Latency'],
             marker='o', linestyle='-', label=f'HTTP Node {node}')
    plt.plot(coap_vanilla_results[coap_vanilla_results['Node'] == node]['Message_Size'],
             coap_vanilla_results[coap_vanilla_results['Node'] == node]['Latency'],
             marker='s', linestyle='-', label=f'CoAP Vanilla Node {node}')
    plt.plot(coap_optimized_results[coap_optimized_results['Node'] == node]['Message_Size'],
             coap_optimized_results[coap_optimized_results['Node'] == node]['Latency'],
             marker='^', linestyle='-', label=f'CoAP Optimized Node {node}')

plt.title('Latency vs Message Size')
plt.xlabel('Message Size')
plt.ylabel('Latency (s)')
plt.legend()
plt.show()

# Similar plots for Throughput, Total Time, etc.
# ...

# %%
# Plot Throughput vs Message Size
plt.figure(figsize=(12, 6))
for node in range(1, 6):
    plt.plot(http_results[http_results['Node'] == node]['Message_Size'], http_results[http_results['Node'] == node]['Throughput'],
             marker='o', linestyle='-', label=f'HTTP Node {node}')
    plt.plot(coap_vanilla_results[coap_vanilla_results['Node'] == node]['Message_Size'],
             coap_vanilla_results[coap_vanilla_results['Node'] == node]['Throughput'],
             marker='s', linestyle='-', label=f'CoAP Vanilla Node {node}')
    plt.plot(coap_optimized_results[coap_optimized_results['Node'] == node]['Message_Size'],
             coap_optimized_results[coap_optimized_results['Node'] == node]['Throughput'],
             marker='^', linestyle='-', label=f'CoAP Optimized Node {node}')

plt.title('Throughput vs Message Size')
plt.xlabel('Message Size')
plt.ylabel('Throughput (Bytes/s)')
plt.legend()
plt.show()

# Plot Total Time vs Node
plt.figure(figsize=(12, 6))
plt.bar(http_results['Node'], http_results['Total_Time'], label='HTTP', alpha=0.7)
plt.bar(coap_vanilla_results['Node'] + 0.2, coap_vanilla_results['Total_Time'], width=0.4, label='CoAP Vanilla', alpha=0.7)
plt.bar(coap_optimized_results['Node'] + 0.4, coap_optimized_results['Total_Time'], width=0.4, label='CoAP Optimized', alpha=0.7)

plt.title('Total Time vs Node')
plt.xlabel('Node')
plt.ylabel('Total Time (s)')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load Vanilla CoAP client results
coap_client_results_vanilla = pd.read_csv('coap_client_results.csv')

# Load CoAP client with Block-Wise Transfer results
coap_client_results_blockwise = pd.read_csv('coap_client_results_garvit.csv')

# Plot CoAP Latency vs Message Size (Vanilla vs Block-Wise)
plt.figure(figsize=(12, 6))
plt.plot(coap_client_results_vanilla['Message_Size'], coap_client_results_vanilla['Latency'], label='Vanilla', marker='o')
plt.plot(coap_client_results_blockwise['Message_Size'], coap_client_results_blockwise['Latency'], label='Message_compression', marker='o')
plt.title('CoAP Latency vs Message Size')
plt.xlabel('Message Size')
plt.ylabel('Latency (s)')
plt.legend()
plt.show()

# Plot CoAP Throughput vs Message Size (Vanilla vs Block-Wise)
plt.figure(figsize=(12, 6))
plt.plot(coap_client_results_vanilla['Message_Size'], coap_client_results_vanilla['Throughput'], label='Vanilla', marker='o')
plt.plot(coap_client_results_blockwise['Message_Size'], coap_client_results_blockwise['Throughput'], label='Message_Compression', marker='o')
plt.title('CoAP Throughput vs Message Size')
plt.xlabel('Message Size')
plt.ylabel('Throughput (Bytes/s)')
plt.legend()
plt.show()

# Plot CoAP Total Time vs Node (Vanilla vs Block-Wise)
plt.figure(figsize=(12, 6))
plt.bar(coap_client_results_vanilla['Node'], coap_client_results_vanilla['Total_Time'], label='Vanilla')
plt.bar(coap_client_results_blockwise['Node'], coap_client_results_blockwise['Total_Time'], label='Message_Compression', alpha=0.7)
plt.title('CoAP Total Time vs Node')
plt.xlabel('Node')
plt.ylabel('Total Time (s)')
plt.legend()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load Vanilla CoAP client results
coap_client_results_vanilla = pd.read_csv('coap_client_results.csv')

# Load CoAP client with Block-Wise Transfer results
coap_client_results_blockwise = pd.read_csv('coap_client_results_cache.csv')

# Plot CoAP Latency vs Message Size (Vanilla vs Block-Wise)
plt.figure(figsize=(12, 6))
plt.plot(coap_client_results_vanilla['Message_Size'], coap_client_results_vanilla['Latency'], label='Vanilla', marker='o')
plt.plot(coap_client_results_blockwise['Message_Size'], coap_client_results_blockwise['Latency'], label='Cached', marker='o')
plt.title('CoAP Latency vs Message Size')
plt.xlabel('Message Size')
plt.ylabel('Latency (s)')
plt.legend()
plt.show()

# Plot CoAP Throughput vs Message Size (Vanilla vs Block-Wise)
plt.figure(figsize=(12, 6))
plt.plot(coap_client_results_vanilla['Message_Size'], coap_client_results_vanilla['Throughput'], label='Vanilla', marker='o')
plt.plot(coap_client_results_blockwise['Message_Size'], coap_client_results_blockwise['Throughput'], label='Cached', marker='o')
plt.title('CoAP Throughput vs Message Size')
plt.xlabel('Message Size')
plt.ylabel('Throughput (Bytes/s)')
plt.legend()
plt.show()

# Plot CoAP Total Time vs Node (Vanilla vs Block-Wise)
plt.figure(figsize=(12, 6))
plt.bar(coap_client_results_vanilla['Node'], coap_client_results_vanilla['Total_Time'], label='Vanilla')
plt.bar(coap_client_results_blockwise['Node'], coap_client_results_blockwise['Total_Time'], label='Cached', alpha=0.7)
plt.title('CoAP Total Time vs Node')
plt.xlabel('Node')
plt.ylabel('Total Time (s)')
plt.legend()
plt.show()
